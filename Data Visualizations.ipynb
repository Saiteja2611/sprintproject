# %%
# %sql
select category, min_kWh from gold_fact_consumption_summary;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select consumption_region, min_kWh from gold_fact_consumption_summary;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select maintenance_asset_id,total_maintenance_cost from gold_fact_maintenance_activity;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select region,TotalConsumption from gold_fact_energy_consumption;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>TotalConsumption</th></tr></thead><tbody><tr><td>EU</td><td>18727.080000000005</td></tr><tr><td>EU</td><td>18293.51999999993</td></tr><tr><td>NA</td><td>17682.800000000017</td></tr><tr><td>NA</td><td>18009.160000000014</td></tr><tr><td>LATAM</td><td>18253.88000000002</td></tr><tr><td>LATAM</td><td>17068.879999999994</td></tr><tr><td>UK</td><td>17715.31999999998</td></tr><tr><td>APAC</td><td>18341.12000000002</td></tr><tr><td>APAC</td><td>18434.80000000003</td></tr><tr><td>UK</td><td>17645.04000000002</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
